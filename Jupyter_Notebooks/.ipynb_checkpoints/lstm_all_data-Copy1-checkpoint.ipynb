# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels as sm
from pathlib import Path
from sklearn.impute import SimpleImputer
sns.set()
# %matplotlib inline
pd.options.plotting.backend
pd.plotting.register_matplotlib_converters()

# %%
covid = pd.read_csv('covid_19_data.csv')

# %%
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285307 entries, 0 to 285306
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              285307 non-null  int64
#  1   ObservationDate  285307 non-null  object
#  2   Province/State   212318 non-null  object
#  3   Country/Region   285307 non-null  object
#  4   Last Update      285307 non-null  object
#  5   Confirmed        285307 non-null  float64
#  6   Deaths           285307 non-null  float64
#  7   Recovered        285307 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 17.4+ MB

# %%
mis = covid.isnull().sum()
mis[mis>0]
# Out:
# Province/State    72989
# dtype: int64

# %%
imputer = SimpleImputer(strategy='constant')
impute_covid = pd.DataFrame(imputer.fit_transform(covid), columns=covid.columns)
impute_covid.head()
# Out:
#   SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0   1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1   2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2   3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3   4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4   5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#   Confirmed Deaths Recovered
# 0         1      0         0
# 1        14      0         0
# 2         6      0         0
# 3         1      0         0
# 4         0      0         0

# %% [markdown]
# ## Process data to right type

# %%
impute_covid['ObservationDate'] = pd.to_datetime(impute_covid['ObservationDate'])
impute_covid['Last Update'] = pd.to_datetime(impute_covid['Last Update'])
impute_covid['Confirmed'] = pd.to_numeric(impute_covid['Confirmed'], errors='coerce')
impute_covid['Recovered'] = pd.to_numeric(impute_covid['Recovered'], errors='coerce')
impute_covid['Deaths'] = pd.to_numeric(impute_covid['Deaths'], errors='coerce')

# %%
impute_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285307 entries, 0 to 285306
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              285307 non-null  object
#  1   ObservationDate  285307 non-null  datetime64[ns]
#  2   Province/State   285307 non-null  object
#  3   Country/Region   285307 non-null  object
#  4   Last Update      285307 non-null  datetime64[ns]
#  5   Confirmed        285307 non-null  float64
#  6   Deaths           285307 non-null  float64
#  7   Recovered        285307 non-null  float64
# dtypes: datetime64[ns](2), float64(3), object(3)
# memory usage: 17.4+ MB

# %%
impute_covid.head(5)
# Out:
#   SNo ObservationDate Province/State  Country/Region         Last Update  \
# 0   1      2020-01-22          Anhui  Mainland China 2020-01-22 17:00:00
# 1   2      2020-01-22        Beijing  Mainland China 2020-01-22 17:00:00
# 2   3      2020-01-22      Chongqing  Mainland China 2020-01-22 17:00:00
# 3   4      2020-01-22         Fujian  Mainland China 2020-01-22 17:00:00
# 4   5      2020-01-22          Gansu  Mainland China 2020-01-22 17:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %% [markdown]
# ### Calculate active confirmed case

# %%
impute_covid['active_confirmed'] = impute_covid['Confirmed'].values - (impute_covid['Deaths'].values + impute_covid['Recovered'].values)

# %%
impute_covid.isnull().sum()[impute_covid.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
impute_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285307 entries, 0 to 285306
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   SNo               285307 non-null  object
#  1   ObservationDate   285307 non-null  datetime64[ns]
#  2   Province/State    285307 non-null  object
#  3   Country/Region    285307 non-null  object
#  4   Last Update       285307 non-null  datetime64[ns]
#  5   Confirmed         285307 non-null  float64
#  6   Deaths            285307 non-null  float64
#  7   Recovered         285307 non-null  float64
#  8   active_confirmed  285307 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(3)
# memory usage: 19.6+ MB

# %%
impute_covid.corr()
# Out:
#                   Confirmed    Deaths  Recovered  active_confirmed
# Confirmed          1.000000  0.885990   0.591882          0.685338
# Deaths             0.885990  1.000000   0.509682          0.614090
# Recovered          0.591882  0.509682   1.000000         -0.181222
# active_confirmed   0.685338  0.614090  -0.181222          1.000000

# %%
features = [['Confirmed', 'Deaths'], ['Confirmed', 'Recovered'], ['Recovered', 'Deaths'], \
            ['Confirmed', 'active_confirmed']]
values = [[impute_covid['Confirmed'], impute_covid['Deaths']],\
          [impute_covid['Confirmed'], impute_covid['Recovered']],\
          [impute_covid['Recovered'], impute_covid['Deaths']],\
          [impute_covid['Confirmed'], impute_covid['active_confirmed']]]

# %%
fig = plt.figure(figsize=(21,11))
fig.subplots_adjust(hspace=0.2, wspace=0.1)
for i in range(1,5):
    ax = fig.add_subplot(2, 2, i)
    col = features[i-1]
    val = values[i-1]
    ax.scatter(val[0], val[1])
    ax.set_xlabel(col[0])
    ax.set_ylabel(col[1])
    ax.set_title('Feature curves')
plt.show()

# %%
start_date = impute_covid.ObservationDate.min()
end_date = impute_covid.ObservationDate.max()
print('Novel Covid-19 information:\n 1. Start date = {}\n 2. End date = {}'.format(start_date, end_date))
# Out:
# Novel Covid-19 information:
#  1. Start date = 2020-01-22 00:00:00
#  2. End date = 2021-05-02 00:00:00

# %%
worldwide = impute_covid[impute_covid['ObservationDate'] == end_date]

# %%
nb_country = len(worldwide['Country/Region'].value_counts()) 
worldwide['Country/Region'].value_counts()
# Out:
# Russia         83
# US             58
# Japan          49
# India          37
# Colombia       34
#                ..
# Thailand        1
# Philippines     1
# Azerbaijan      1
# Ecuador         1
# Paraguay        1
# Name: Country/Region, Length: 194, dtype: int64

# %%
world = worldwide.groupby('Country/Region').sum()
world = world.sort_values(by=['Confirmed'], ascending=False)
world.head()
# Out:
#                  Confirmed    Deaths   Recovered  active_confirmed
# Country/Region
# US              32421534.0  577045.0         0.0        31844489.0
# India           19557457.0  215542.0  15992271.0         3349644.0
# Brazil          14754910.0  407639.0  13083550.0         1263721.0
# France           5713393.0  104980.0    362043.0         5246370.0
# Turkey           4875388.0   40844.0   4480381.0          354163.0

# %%
print('================ Worldwide report ===============================')
print('== Information to {} on novel COVID-19 =========\n'.format(end_date))
print('Tota confirmed: {}\nTotal Deaths: {}\nTotal Recovered: {}\nTotal active confirmed: {}\n\
Total country Recorded: {} \n'.format(\
worldwide.Confirmed.sum(), worldwide.Deaths.sum(), worldwide.Recovered.sum(), worldwide.active_confirmed.sum(),\
                                     nb_country))
print('==================================================================')
# Out:
# ================ Worldwide report ===============================
# == Information to 2021-05-02 00:00:00 on novel COVID-19 =========
#
# Tota confirmed: 152502340.0
# Total Deaths: 3199106.0
# Total Recovered: 89311961.0
# Total active confirmed: 59991273.0
# Total country Recorded: 194
#
# ==================================================================

# %%
world_table = world.reset_index()

# %%
x = world_table[world_table['Country/Region'] == 'France']
big_7 = world_table[world_table['Confirmed'] >= x.iloc[0,1]]

# %%
big_7.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col1,#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col2,#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col4,#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col3{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col3,#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col4,#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col1,#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col2{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col1{
#             background-color:  #1f948c;
#             color:  #000000;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col2{
#             background-color:  #3d4d8a;
#             color:  #f1f1f1;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col4{
#             background-color:  #481a6c;
#             color:  #f1f1f1;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col1{
#             background-color:  #30698e;
#             color:  #f1f1f1;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col2{
#             background-color:  #2db27d;
#             color:  #000000;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col3{
#             background-color:  #86d549;
#             color:  #000000;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col3{
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }#T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col4{
#             background-color:  #472e7c;
#             color:  #f1f1f1;
#         }</style><table id="T_838da95c_b2a3_11eb_bdff_4c32758cedbf" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Confirmed</th>        <th class="col_heading level0 col2" >Deaths</th>        <th class="col_heading level0 col3" >Recovered</th>        <th class="col_heading level0 col4" >active_confirmed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_838da95c_b2a3_11eb_bdff_4c32758cedbflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col0" class="data row0 col0" >US</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col1" class="data row0 col1" >32421534.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col2" class="data row0 col2" >577045.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow0_col4" class="data row0 col4" >31844489.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_838da95c_b2a3_11eb_bdff_4c32758cedbflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col0" class="data row1 col0" >India</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col1" class="data row1 col1" >19557457.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col2" class="data row1 col2" >215542.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col3" class="data row1 col3" >15992271.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow1_col4" class="data row1 col4" >3349644.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_838da95c_b2a3_11eb_bdff_4c32758cedbflevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col0" class="data row2 col0" >Brazil</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col1" class="data row2 col1" >14754910.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col2" class="data row2 col2" >407639.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col3" class="data row2 col3" >13083550.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow2_col4" class="data row2 col4" >1263721.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_838da95c_b2a3_11eb_bdff_4c32758cedbflevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col0" class="data row3 col0" >France</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col1" class="data row3 col1" >5713393.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col2" class="data row3 col2" >104980.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col3" class="data row3 col3" >362043.000000</td>
#                         <td id="T_838da95c_b2a3_11eb_bdff_4c32758cedbfrow3_col4" class="data row3 col4" >5246370.000000</td>
#             </tr>
#     </tbody></table>

# %%
axs = big_7.plot('Country/Region', ['Confirmed', 'Deaths', 'Recovered', 'active_confirmed'], kind='barh',\
                 stacked=True, title='Country most affected by novel covid-19',\
                 figsize=(20,10.5),colormap='rainbow_r', logx=True, legend=True) 
pd.plotting.table(data=world_table, rowLabels=world.index, colLabels=world.columns, ax=axs)
plt.xlabel(' ')
# Out:
# Text(0.5, 0, ' ')

# %% [markdown]
# ## China

# %%
china = impute_covid[impute_covid['Country/Region'] == 'Mainland China']

# %%
chstar_date = china.ObservationDate.min()
chend_date = china.ObservationDate.max()

# %%
print('Novel covid-19 China:\n start date = {}\n end date = {}'.format(chstar_date, chend_date))
# Out:
# Novel covid-19 China:
#  start date = 2020-01-22 00:00:00
#  end date = 2021-05-02 00:00:00

# %%
lastChina = china[china['ObservationDate'] == chend_date]
lastChina.head()
# Out:
#            SNo ObservationDate Province/State  Country/Region  \
# 284736  284737      2021-05-02          Anhui  Mainland China
# 284770  284771      2021-05-02        Beijing  Mainland China
# 284820  284821      2021-05-02      Chongqing  Mainland China
# 284862  284863      2021-05-02         Fujian  Mainland China
# 284867  284868      2021-05-02          Gansu  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered  active_confirmed
# 284736 2021-05-03 04:20:39      994.0     6.0      988.0               0.0
# 284770 2021-05-03 04:20:39     1057.0     9.0     1043.0               5.0
# 284820 2021-05-03 04:20:39      596.0     6.0      585.0               5.0
# 284862 2021-05-03 04:20:39      593.0     1.0      566.0              26.0
# 284867 2021-05-03 04:20:39      193.0     2.0      190.0               1.0

# %%
print('================ China report ===================================')
print('== Information to {} on novel COVID-19 =========\n'.format(chend_date))
print('Tota confirmed: {}\nTotal Deaths: {}\nTotal Recovered: {}\nTotal active confirmed: {}\n'.format(\
lastChina.Confirmed.sum(), lastChina.Deaths.sum(), lastChina.Recovered.sum(), lastChina.active_confirmed.sum()))
print('==================================================================')
# Out:
# ================ China report ===================================
# == Information to 2021-05-02 00:00:00 on novel COVID-19 =========
#
# Tota confirmed: 90697.0
# Total Deaths: 4636.0
# Total Recovered: 85738.0
# Total active confirmed: 323.0
#
# ==================================================================

# %%
lastChina[['Province/State', 'Confirmed', 'Deaths', 'Recovered', 'active_confirmed']].style.\
background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow0_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow0_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow1_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow13_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow16_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow16_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow22_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow22_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow25_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow25_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow29_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow29_col3{
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow0_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow1_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow2_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow3_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow4_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow4_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow4_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow5_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow6_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow7_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow7_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow7_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow8_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow8_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow8_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow9_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow10_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow13_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow14_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow15_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow16_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow17_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow18_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow19_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow19_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow19_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow20_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow20_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow20_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow21_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow22_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow23_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow24_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow24_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow24_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow25_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow26_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow27_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow27_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow27_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow28_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow28_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow28_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow28_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow29_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow30_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow31_col2{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow0_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow7_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow9_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow10_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow16_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow17_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow18_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow19_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow20_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow27_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow29_col4{
#             background-color:  #482979;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow1_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow9_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow11_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow13_col3{
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow1_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow2_col4{
#             background-color:  #433e85;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow2_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow2_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow3_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow3_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow15_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow15_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow17_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow17_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow21_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow21_col3{
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow3_col4{
#             background-color:  #25858e;
#             color:  #000000;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow4_col4{
#             background-color:  #472e7c;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow5_col1{
#             background-color:  #470d60;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow5_col3{
#             background-color:  #470e61;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow5_col4{
#             background-color:  #8ed645;
#             color:  #000000;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow6_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow6_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow11_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow14_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow14_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow18_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow18_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow26_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow26_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow30_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow30_col3{
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow6_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow12_col4{
#             background-color:  #424186;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow8_col4{
#             background-color:  #30698e;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow9_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow11_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow31_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow31_col3{
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow10_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow10_col3{
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow11_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow22_col4{
#             background-color:  #46327e;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow12_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow12_col2,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow12_col3,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow23_col4{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow13_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow14_col4{
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow15_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow24_col4,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow26_col4{
#             background-color:  #3e4989;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow21_col4{
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow23_col1,#T_330f4d72_b2a4_11eb_bdff_4c32758cedbfrow23_col3{
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }#T_330f4d72_b2a4_11eb_bdff

# %% [markdown]
# ## Province confirmed, recovered and death

# %%
province = lastChina.groupby('Province/State').sum()
province = province.sort_values(by=['Confirmed'], ascending=False)

# %%
province.plot(kind='bar', label='Confirmed',logy=True,figsize=(20,10), stacked=True,\
              title='China Province  with novel covid-19')
plt.ylabel('Total patient')
# Out:
# Text(0, 0.5, 'Total patient')

# %%
conf_china = china.groupby('ObservationDate')['Confirmed'].agg('sum')
rec_china = china.groupby('ObservationDate')['Recovered'].agg('sum')
dea_china = china.groupby('ObservationDate')['Deaths'].agg('sum')
ac_china = china.groupby('ObservationDate')['active_confirmed'].agg('sum')

# %% [markdown]
# ## Beside China

# %%
rest_world = impute_covid[impute_covid['Country/Region'] != 'Mainland China']

# %%
rest_world.head()
# Out:
#    SNo ObservationDate Province/State Country/Region         Last Update  \
# 12  13      2020-01-22      Hong Kong      Hong Kong 2020-01-22 17:00:00
# 20  21      2020-01-22          Macau          Macau 2020-01-22 17:00:00
# 28  29      2020-01-22         Taiwan         Taiwan 2020-01-22 17:00:00
# 31  32      2020-01-22     Washington             US 2020-01-22 17:00:00
# 35  36      2020-01-22  missing_value          Japan 2020-01-22 17:00:00
#
#     Confirmed  Deaths  Recovered  active_confirmed
# 12        0.0     0.0        0.0               0.0
# 20        1.0     0.0        0.0               1.0
# 28        1.0     0.0        0.0               1.0
# 31        1.0     0.0        0.0               1.0
# 35        2.0     0.0        0.0               2.0

# %%
print('Novel covid-19 ROW:\n start date = {}\n end date = {}'.format(rest_world.ObservationDate.min(),\
                    rest_world.ObservationDate.max()))
# Out:
# Novel covid-19 ROW:
#  start date = 2020-01-22 00:00:00
#  end date = 2021-05-02 00:00:00

# %%
row = rest_world[rest_world['ObservationDate'] == rest_world.ObservationDate.max()]

# %%
rw = row[['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'active_confirmed']].\
groupby('Country/Region').sum()
rwx = rw.sort_values(by=['Confirmed'], ascending=False)
rwx.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow0_col0,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow0_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow0_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow1_col2{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow0_col2,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow6_col2,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow11_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow16_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow17_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow18_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow19_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow20_col2,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow21_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow22_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow23_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow24_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow25_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow26_col2,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow27_col2,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow28_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow29_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow30_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow32_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow33_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow34_col2,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow36_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow37_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow38_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow39_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow39_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow40_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow41_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow42_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow42_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow43_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow44_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow45_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow46_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow47_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow48_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow50_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow51_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow52_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow53_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow54_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow55_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow56_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow57_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow58_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow58_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow59_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow60_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow61_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow62_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow63_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow64_col2,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow65_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow66_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow67_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow68_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow69_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow71_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow71_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow72_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow73_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow73_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow74_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow75_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow75_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow76_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow76_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow77_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow78_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow78_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow79_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow80_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow81_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow82_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow83_col0,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow83_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow83_col3,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow84_col0,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow84_col1,#T_67d34f3a_b2a5_11eb_bdff_4c32758cedbfrow8 ...

# %%
rwx.plot(kind='bar', figsize=(20,10), stacked=True, title='novel covid-19 in the rest of world', logy=True)
plt.ylabel('Total patient')
# Out:
# Text(0, 0.5, 'Total patient')

# %%
obs_conf_world = rest_world.groupby('ObservationDate')['Confirmed'].aggregate([np.sum]) # confirmed obs
ac_conf_world = rest_world.groupby('ObservationDate')['active_confirmed'].aggregate([np.sum]) # last upd obs
patient_world_r = rest_world.groupby('ObservationDate')['Recovered'].aggregate([np.sum]) # lifetime 
patient_world_dea = rest_world.groupby('ObservationDate')['Deaths'].aggregate([np.sum]) # lifetime

# %%
obs_conf_world.columns = ['Confirmed']
ac_conf_world.columns = ['active_onfirmed']
patient_world_r.columns = ['Recovered'] 
patient_world_dea.columns = ['Deaths']

# %% [markdown]
# # Builde Model

# %%
from sklearn.preprocessing import MinMaxScaler
import datetime
from keras.layers.recurrent import GRU
from keras.layers import Dense, Input, Dropout 
from keras.models import Model 
from keras.models import load_model 
from keras.callbacks import ModelCheckpoint

# %%
confirmed_case = impute_covid[['ObservationDate', 'Confirmed']]
confirmed_case = confirmed_case.set_index('ObservationDate')

# %%
confirmed_case.head(3)
# Out:
#                  Confirmed
# ObservationDate
# 2020-01-22             1.0
# 2020-01-22            14.0
# 2020-01-22             6.0

# %%
sns.violinplot(confirmed_case.Confirmed)
plt.title('confirmed case violin boxplot')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'confirmed case violin boxplot')

# %%
scaler = MinMaxScaler(feature_range=(0,1))
confirmed_case['scaled_cases']= scaler.fit_transform(np.array(confirmed_case.Confirmed).reshape(-1,1))

# %%
confirmed_case
# Out:
#                  Confirmed  scaled_cases
# ObservationDate
# 2020-01-22             1.0      0.051257
# 2020-01-22            14.0      0.051259
# 2020-01-22             6.0      0.051258
# 2020-01-22             1.0      0.051257
# 2020-01-22             0.0      0.051257
# ...                    ...           ...
# 2021-05-02         96531.0      0.067595
# 2021-05-02         26045.0      0.055665
# 2021-05-02          1344.0      0.051484
# 2021-05-02         84641.0      0.065582
# 2021-05-02        359327.0      0.112073
#
# [285307 rows x 2 columns]

# %%
confirmed_case.head()
# Out:
#                  Confirmed  scaled_cases
# ObservationDate
# 2020-01-22             1.0      0.051257
# 2020-01-22            14.0      0.051259
# 2020-01-22             6.0      0.051258
# 2020-01-22             1.0      0.051257
# 2020-01-22             0.0      0.051257

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig = plt.figure(figsize=(15, 5.5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax1  = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
plot_acf(confirmed_case.scaled_cases, ax=ax1, lags=10)
plot_pacf(confirmed_case.scaled_cases, ax=ax2, lags=10)
plt.show()

# %%
split_date = end_date - datetime.timedelta(days=3) + datetime.timedelta(hours=23, minutes=59,seconds=59)
train = confirmed_case[confirmed_case.index <= split_date]
test = confirmed_case[confirmed_case.index > split_date]

# %%
split_date
# Out:
# Timestamp('2021-04-29 23:59:59')

# %%
print('train shape: {}\ntest shape : {}'.format(train.shape, test.shape))
# Out:
# train shape: (283015, 2)
# test shape : (2292, 2)

# %%
def makeXy(ts, nb_timesteps): 
    X = [] 
    y = [] 
    for i in range(nb_timesteps, ts.shape[0]): 
        
        X.append(list(ts.iloc[i-nb_timesteps:i])) 
        y.append(ts.iloc[i]) 
    X, y = np.array(X), np.array(y) 
    return X, y

# %%
lookback = 2 # 3days back 

X_train, y_train = makeXy(train['scaled_cases'], lookback) 
print('Shape of train arrays:', X_train.shape, y_train.shape) 

X_test, y_test = makeXy(test['scaled_cases'], lookback) 
print('Shape of test arrays:', X_test.shape, y_test.shape)
# Out:
# Shape of train arrays: (283013, 2) (283013,)
# Shape of test arrays: (2290, 2) (2290,)

# %%
Xtrain = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))

Xtest = X_test.reshape((X_test.shape[0], X_test.shape[1], 1)) 

n=  Xtrain.shape[1]
print('Shape of 3D arrays:', Xtrain.shape, Xtest.shape)
# Out:
# Shape of 3D arrays: (283013, 2, 1) (2290, 2, 1)

# %%
np.random.seed(7)

# %%
input_layer = Input(shape=(n,1), dtype='float32')

# %%
gru_layer1 = GRU(64, input_shape=(n,1), return_sequences=True)(input_layer)
gru_layer2 = GRU(32, input_shape=(n,64), return_sequences=False)(gru_layer1)

# %%
dropout_layer = Dropout(0.2)(gru_layer2)

# %%
output_layer = Dense(1, activation='linear')(dropout_layer)

# %%
model = Model(inputs=input_layer, outputs=output_layer)
model.compile(loss='mean_squared_error', optimizer='rmsprop')
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# gru (GRU)                    (None, 2, 64)             12864
# _________________________________________________________________
# gru_1 (GRU)                  (None, 32)                9408
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 22,305
# Trainable params: 22,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=Xtrain, y=y_train, batch_size=32, epochs=20,verbose=1, validation_data=(Xtest, y_test))
# Out:
# Epoch 1/20
# 8845/8845 [==============================] - 36s 4ms/step - loss: 0.0017 - val_loss: 0.0078
# Epoch 2/20
# 8845/8845 [==============================] - 35s 4ms/step - loss: 0.0016 - val_loss: 0.0074
# Epoch 3/20
# 8845/8845 [==============================] - 34s 4ms/step - loss: 0.0017 - val_loss: 0.0074
# Epoch 4/20
# 8845/8845 [==============================] - 33s 4ms/step - loss: 0.0016 - val_loss: 0.0077
# Epoch 5/20
# 8845/8845 [==============================] - 39s 4ms/step - loss: 0.0016 - val_loss: 0.0075
# Epoch 6/20
# 8845/8845 [==============================] - 43s 5ms/step - loss: 0.0016 - val_loss: 0.0074
# Epoch 7/20
# 8845/8845 [==============================] - 44s 5ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 8/20
# 8845/8845 [==============================] - 42s 5ms/step - loss: 0.0017 - val_loss: 0.0073
# Epoch 9/20
# 8845/8845 [==============================] - 35s 4ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 10/20
# 8845/8845 [==============================] - 37s 4ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 11/20
# 8845/8845 [==============================] - 39s 4ms/step - loss: 0.0016 - val_loss: 0.0074
# Epoch 12/20
# 8845/8845 [==============================] - 41s 5ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 13/20
# 8845/8845 [==============================] - 41s 5ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 14/20
# 8845/8845 [==============================] - 46s 5ms/step - loss: 0.0016 - val_loss: 0.0072
# Epoch 15/20
# 8845/8845 [==============================] - 42s 5ms/step - loss: 0.0017 - val_loss: 0.0073
# Epoch 16/20
# 8845/8845 [==============================] - 42s 5ms/step - loss: 0.0017 - val_loss: 0.0074
# Epoch 17/20
# 8845/8845 [==============================] - 42s 5ms/step - loss: 0.0016 - val_loss: 0.0077
# Epoch 18/20
# 8845/8845 [==============================] - 42s 5ms/step - loss: 0.0017 - val_loss: 0.0075
# Epoch 19/20
# 8845/8845 [==============================] - 40s 4ms/step - loss: 0.0016 - val_loss: 0.0073
# Epoch 20/20
# 8845/8845 [==============================] - 39s 4ms/step - loss: 0.0016 - val_loss: 0.0076

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
preds = model.predict(x_test)
pred_covid19 = scaler.inverse_transform(preds)
pred_covid19 = np.squeeze(pred_covid19)

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = np.sqrt(mean_squared_error(test.Confirmed.iloc[n:] , pred_covid19))
print('RMSE for the test set:', round(rmse, 4))
# Out:
# RMSE for the test set: 509373.3115

# %%
actual_pred = pd.DataFrame()
actual_pred['actual'] = test.Confirmed.iloc[n:]
actual_pred['predict'] =  pred_covid19

# %%
valid = actual_pred.reset_index()

# %%
valid
# Out:
#           index     actual        predict
# 0    2021-04-30   122108.0  117198.109375
# 1    2021-04-30    13232.0  115374.289062
# 2    2021-04-30    26652.0   75199.148438
# 3    2021-04-30     1232.0   50101.179688
# 4    2021-04-30  2977363.0   34708.308594
# ...         ...        ...            ...
# 2285 2021-05-02    96531.0   82743.000000
# 2286 2021-05-02    26045.0  105589.820312
# 2287 2021-05-02     1344.0   78347.343750
# 2288 2021-05-02    84641.0   34394.265625
# 2289 2021-05-02   359327.0   88275.757812
#
# [2290 rows x 3 columns]

# %%
valid.groupby('index').sum().plot(kind='bar')
plt.ylabel(' Total confirmed')
plt.title('Predicted VS Actual Confirme Case')
plt.xlabel('ObservationDate')
# Out:
# Text(0.5, 0, 'ObservationDate')

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer,Embedding,SpatialDropout1D
from tensorflow.keras.callbacks import TensorBoard,EarlyStopping
from tensorflow.keras.models import Sequential

# %%
activation="sigmoid"
loss="binary_crossentropy"
metrics=['accuracy']
optimizer='adam'
epochs=20

TFmodel= Sequential()
TFmodel.add(Embedding(30000, 64, input_length=1))
TFmodel.add(SpatialDropout1D(0.2))
TFmodel.add(Dense(1, activation=activation))
TFmodel.compile(loss=loss, metrics=metrics, optimizer=optimizer)

# %%
tensorboard = TensorBoard(log_dir='logs')
earlystopping = EarlyStopping(mode='min', patience=3, restore_best_weights=True)
history = TFmodel.fit(Xtrain,y_train,epochs=epochs, batch_size=64, callbacks=[tensorboard,earlystopping], validation_data=(Xtest, y_test),)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (None, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 2).
# WARNING:tensorflow:Model was constructed with shape (None, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 2).
# 4421/4423 [============================>.] - ETA: 0s - loss: 0.2681 - accuracy: 1.7953e-06WARNING:tensorflow:Model was constructed with shape (None, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 2).
# 4423/4423 [==============================] - 48s 11ms/step - loss: 0.2681 - accuracy: 1.7965e-06 - val_loss: 0.2945 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 4423/4423 [==============================] - 49s 11ms/step - loss: 0.2390 - accuracy: 3.9904e-06 - val_loss: 0.2945 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 4423/4423 [==============================] - 49s 11ms/step - loss: 0.2388 - accuracy: 2.6345e-06 - val_loss: 0.2939 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 4423/4423 [==============================] - 54s 12ms/step - loss: 0.2384 - accuracy: 7.9121e-07 - val_loss: 0.2951 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 4423/4423 [==============================] - 51s 11ms/step - loss: 0.2382 - accuracy: 3.8683e-07 - val_loss: 0.2944 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 4423/4423 [==============================] - 51s 12ms/step - loss: 0.2379 - accuracy: 9.4638e-06 - val_loss: 0.2930 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 4423/4423 [==============================] - 50s 11ms/step - loss: 0.2382 - accuracy: 1.6337e-07 - val_loss: 0.2945 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 4423/4423 [==============================] - 58s 13ms/step - loss: 0.2379 - accuracy: 5.1462e-08 - val_loss: 0.2947 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 4423/4423 [==============================] - 51s 11ms/step - loss: 0.2380 - accuracy: 1.9678e-06 - val_loss: 0.2943 - val_accuracy: 0.0000e+00

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
