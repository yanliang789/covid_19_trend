# %%
import pandas as pd

# %%
df = pd.read_csv("Confirmed_VS_Vaccinated_US.csv")
df
# Out:
#     Unnamed: 0 ObservationDate Country   Confirmed  People_Fully_Vaccinated
# 0          333      2020-12-20      US  17925587.0                      0.0
# 1          334      2020-12-21      US  18123968.0                      0.0
# 2          335      2020-12-22      US  18321157.0                      0.0
# 3          336      2020-12-23      US  18550002.0                      0.0
# 4          337      2020-12-24      US  18743916.0                      0.0
# ..         ...             ...     ...         ...                      ...
# 65         398      2021-02-23      US  28261595.0               19882544.0
# 66         399      2021-02-24      US  28336097.0               20607261.0
# 67         400      2021-02-25      US  28413388.0               21555117.0
# 68         401      2021-02-26      US  28486394.0               22613359.0
# 69         402      2021-02-27      US  28554465.0               23698627.0
#
# [70 rows x 5 columns]
